# %% [markdown]
# ### Getting into Class
# This exercise is to get you familiar with the idea of creating your own class object.
#
# This will create a generic Student class that we will be able to extend with other class objects.
#
# Your Class should be able to create an Student object instance with the following properties
#
# - Construct with default attributes for School Name, Student First Name, and Last Name
# - Methods to update any of these above attributes
# - An overloaded method for the str() function to return the Student attributes in a string formatted sentence "{FirstName} {LastName} is a student of {SchoolName}"
#
# You are free to implement this class however you like. The testing code is included below. Don't be afraid to check the [documentation]('https://docs.python.org/3/tutorial/classes.html') or any other resources you would like! Internet searching is a big part of promgramming

# %%
class Student ():
    
    def __init__(self, schoolName, studentName, studentLastName, schoolYear):
        self.schoolName = schoolName
        self.studentName = studentName
        self.studentLastName = studentLastName
        self.schoolYear = schoolYear
    
    def setStudentName (self, new_name):
        self.studentName = new_name
        
    def getStudentName (self):
        return self.studentName 

    def __str__ (self):
        return f'{self.studentName} {self.studentLastName} is a student of {self.schoolName}, class {self.schoolYear}'


cecile = Student("Parsons", "Cecile", "Roca","2022")
cecile.setStudentName ('Cece')

print (cecile.getStudentName())
print (cecile)
# Out:
# Cece
# Cece Roca is a student of Parsons, class 2022

# %% [markdown]
# ### Challenges
# Before looking at any of these specific challenges, look back at the class you've created. Are there features of Students that you think are missing? Go ahead and just try and add them yourself! These can be things like registered classes, graduation year, enrollment status, etc. Anything you can think of! Class flexibility is designed so that your approach reflects your own personal understanding of the problem. But for a more structured challenge read on...
#
# The challenges here extend the functionality of the base class. These are in topics of class attributes, magic methods, inheritance, and iteration. Don't be afraid to check python documentation on these problems to look for implementation help! No one codes alone!
#
# Class is where your own ideas get to come through as a programmer and designer. So there is no one right way to any of these. Give it your best shot and also be creative!
#
# __Challenge #1__ add an class wide attribute student count and give every student an ID
# Create a Class wide count of students that tracks how many students have been created. Then, usi that attriute to give every student a unique ID.
#
# __Challenge #2__ add a behavioral method to the students
# What kind of behavior should a student have? What do they do? Do they study? Research? Maybe a student can declare a major or focus of study?
#
# Implement the method and the appropriate attributes that allows a student to print a statement about themselves. These can be as simple as "say my own name" or something like printing the student's favorite faculty member
#
# __Challenge #3__ create a subclass called Graduate Student
# The Graduate student should inherit from the base Student class. How do you think Graduate Students should be differentiated from the base Student? Add your own attribute or methods that you think they should have.
#
# __Challenge #4__ Create a School Class that has Students as attributes
# This is a separate class that is called School that can enroll Students, and graduate students. Maybe it can track its own endowment. This would be a large class that is meant to process these students in some way.

# %%
#Challenge #1
class Student ():
    #Atribute part of the class definition, that allow us to increase the value 
    studentID = 0
    
    def __init__(self, schoolName, studentName, studentLastName):
        self.schoolName = schoolName
        self.studentName = studentName
        self.studentLastName = studentLastName
        Student.studentID += 1
        self.studentID = Student.studentID
        
    
    def setStudentName (self, new_name):
        self.studentName = new_name
        
    def getStudentName (self):
        return self.studentName 
    
    def setStudentLastName (self, new_lastname):
        self.studentLastName = new_lastname
        
    def getStudentLastName (self):
        return self.studentLastName 
    
    def getStudentID (self):
        return self.studentID 

    def __str__ (self):
        return f'{self.studentName} {self.studentLastName} is a student of {self.schoolName}, with the ID number {self.studentID}'


cecile = Student("Parsons", "Cecile", "Roca")
#cecile.setStudentName ('Cece')
mat = Student("Parsons", "Mat", "Finder")
#print(mat.getStudentID())
dave = Student("Parsons", "Dave", "Barkas")
#print(dave.getStudentID())
caitlin = Student ("Parsons", "Caitlin", "Morris")
print (cecile)
print (mat)
print (dave)
print (caitlin)
# Out:
# Cecile Roca is a student of Parsons, with the ID number 1
# Mat Finder is a student of Parsons, with the ID number 2
# Dave Barkas is a student of Parsons, with the ID number 3
# Caitlin Morris is a student of Parsons, with the ID number 4

# %%
# Challenge 2 

class Student ():
    #Atribute part of the class definition, that allow us to increase the value 
    studentID = 0
    
    
    def __init__(self, schoolName, studentName, studentLastName, hobby, favClass):
        self.schoolName = schoolName
        self.studentName = studentName
        self.studentLastName = studentLastName
        Student.studentID += 1
        self.studentID = Student.studentID
        self.hobby = hobby
        self.favClass = favClass
        
    
    def setSchoolName (self, new_schoolname):
        self.schoolName = new_schoolname
        
    def getSchoolName (self):
        return self.schoolname
    
    def setStudentName (self, new_name):
        self.studentName = new_name
        
    def getStudentName (self):
        return self.studentName 
    
    def setStudentLastName (self, new_lastName):
        self.studentLastName = new_lastName
        
    def getStudentLastName (self):
        return self.studentLastName 
    
    def getStudentID (self):
        return self.studentID
    
    def setHobby (self, new_hobby):
        self.hobby = new_hobby
    
    def printHobby (self):
        print(self.hobby)
    
    def setFavClass (self, new_favClass):
        self.favClass = new_favClass
        
    def getFavClass (self):
        return self.favClass


    def __str__ (self):
        return f'I am {self.studentName} {self.studentLastName} a student of {self.schoolName}, with the ID number {self.studentID}. {self.hobby} and {self.favClass}'

cecile = Student("Parsons", "Cecile", "Roca","painting","UX Design")
cecile.setHobby ("I like painting on canvas")
mat = Student("Brown", "Mat", "Finder","gardening","Sound Design")
mat.setHobby ("I like gardening")
dave = Student("Cornell", "Dave", "Barkas", "cars", "accounting")
dave.setHobby ("I like cars")
caitlin = Student ("MIT", "Caitlin", "Morris","coding","Architecture")
caitlin.setHobby ("I like coding in C++")
cecile.printHobby ()
print (cecile)
mat.printHobby ()
print (mat)
dave.printHobby ()
print (dave)
caitlin.printHobby ()
print (caitlin)
# Out:
# I like painting on canvas
# I am Cecile Roca a student of Parsons, with the ID number 1. I like painting on canvas and UX Design
# I like gardening
# I am Mat Finder a student of Brown, with the ID number 2. I like gardening and Sound Design
# I like cars
# I am Dave Barkas a student of Cornell, with the ID number 3. I like cars and accounting
# I like coding in C++
# I am Caitlin Morris a student of MIT, with the ID number 4. I like coding in C++ and Architecture

# %%
# challenge 3
class GradStudent (Student):
    def __init__(self, yearProgram, programName, schoolName, studentName, studentLastName, hobby, favClass):
        super().__init__(schoolName, studentName, studentLastName, hobby, favClass)
        self.yearProgram = yearProgram
        self.programName = programName  
    
    def setYearProgram (self, new_yearProgram):
        self.yearProgram = new_yearProgram
        
    def getYearProgram (self):
        return self.yearProgram
    
    def setProgramName (self, new_programName):
        self.programName = new_programName
        
    def getProgramName (self):
        return self.programName
    
    def __str__ (self):
        return f'After {self.yearProgram}, he will graduate from {self.programName} at {self.schoolName}. Currently, {self.studentName} {self.studentLastName} with the ID number {self.studentID} likes {self.hobby} and {self.favClass}'

    
peter = GradStudent ("2022","MFADT","Parsons","Peter", "Smith", "dance", "python" )   
print (peter)
# Out:
# After 2022, he will graduate from MFADT at Parsons. Currently, Peter Smith with the ID number 5 likes dance and python

# %%
# challenge 4 

class School ():
    def __init__(self, schoolName):
        self.name = name
        self.students = []
    
    def addStudent (self,student):
        self.students.append(student)
    
    def getStudents(self):
        # returns all students
        return self.students
    
    def getStudentByID(self, studentID):
        # returns the student with studentID, or returns None if student doesn't exist
        # Loop through students
        for student in self.students:
            # find student with ID == studentID
            if student.getStudentID() == studentID:
                return student
        
        return None

parsons = School("Parsons")
parsons.addStudent(cecile)
parsons.addStudent(dave)
parsons.addStudent(mat)

print(cecile.getStudentID())

print(parsons.getStudentByID(1))
            
print (parsons.getStudentByID(3))
print(dave.getStudentID())
# Out:
# 1
# I am Cecile Roca a student of Parsons, with the ID number 1. I like painting on canvas and UX Design
# I am Dave Barkas a student of Cornell, with the ID number 3. I like cars and accounting
# 3
